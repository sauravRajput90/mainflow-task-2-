# %% [markdown]
# # Data Manipulation with pandas

# %%
# Import The Library
import pandas as pd

# %%
# Reading The Dataset
df = pd.read_csv('E:\postings.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# concise summary 
df.info
# Out:
# <bound method DataFrame.info of             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192                              NaN
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263                              NaN
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# ...

# %%
# Generate Descriptive Statistics
df.describe()
# Out:
#              job_id    max_salary    company_id          views     med_salary  \
# count  1.238490e+05  2.979300e+04  1.221320e+05  122160.000000    6280.000000
# mean   3.896402e+09  9.193942e+04  1.220401e+07      14.618247   22015.619876
# std    8.404355e+07  7.011101e+05  2.554143e+07      85.903598   52255.873846
# min    9.217160e+05  1.000000e+00  1.009000e+03       1.000000       0.000000
# 25%    3.894587e+09  4.828000e+01  1.435200e+04       3.000000      18.940000
# 50%    3.901998e+09  8.000000e+04  2.269650e+05       4.000000      25.500000
# 75%    3.904707e+09  1.400000e+05  8.047188e+06       8.000000    2510.500000
# max    3.906267e+09  1.200000e+08  1.034730e+08    9975.000000  750000.000000
#
#          min_salary       applies  original_listed_time  remote_allowed  \
# count  2.979300e+04  23320.000000          1.238490e+05         15246.0
# mean   6.491085e+04     10.591981          1.713152e+12             1.0
# ...

# %%
# remove duplicate rows
df=df.drop_duplicates()
df
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192                              NaN
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263                              NaN
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# ...

# %%
# detect missing values
df.isnull()
# Out:
#         job_id  company_name  title  description  max_salary  pay_period  \
# 0        False         False  False        False       False       False
# 1        False          True  False        False       False       False
# 2        False         False  False        False       False       False
# 3        False         False  False        False       False       False
# 4        False          True  False        False       False       False
# ...        ...           ...    ...          ...         ...         ...
# 123844   False         False  False        False       False       False
# 123845   False         False  False        False        True        True
# 123846   False         False  False        False        True        True
# 123847   False         False  False        False        True        True
# 123848   False         False  False        False       False       False
#
#         location  company_id  views  med_salary  ...  expiry  closed_time  \
# ...

# %%
# total number of missing values 
df.isnull().sum()
# Out:
# job_id                             0
# company_name                    1719
# title                              0
# description                        7
# max_salary                     94056
# pay_period                     87776
# location                           0
# company_id                      1717
# views                           1689
# med_salary                    117569
# min_salary                     94056
# formatted_work_type                0
# applies                       100529
# original_listed_time               0
# remote_allowed                108603
# job_posting_url                    0
# application_url                36665
# application_type                   0
# expiry                             0
# closed_time                   122776
# formatted_experience_level     29409
# skills_desc                   121410
# listed_time                        0
# posting_domain                 39968
# sponsored                          0
# ...

# %%
# detects existing (non-missing) values
df.notnull()
# Out:
#         job_id  company_name  title  description  max_salary  pay_period  \
# 0         True          True   True         True        True        True
# 1         True         False   True         True        True        True
# 2         True          True   True         True        True        True
# 3         True          True   True         True        True        True
# 4         True         False   True         True        True        True
# ...        ...           ...    ...          ...         ...         ...
# 123844    True          True   True         True        True        True
# 123845    True          True   True         True       False       False
# 123846    True          True   True         True       False       False
# 123847    True          True   True         True       False       False
# 123848    True          True   True         True        True        True
#
#         location  company_id  views  med_salary  ...  expiry  closed_time  \
# ...

# %%
#  total number of missing values in the entire DataFrame
df.isnull().sum().sum()
# Out:
# 1133501

# %%
# replace missing values (NaN)
df2=df.fillna(0)
df2
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192                                0
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263                                0
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# ...

# %%
# fill missing values (NaN)
# it replaces it with the value from the previous row that is not null
df3=df.fillna(method='pad')
df3
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192            Corcoran Sawyer Smith
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263           Abrams Fensterman, LLP
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# ...

# %%
# fill missing values (NaN)
# it replaces it with the value from the next row that is not null
df4=df.fillna(method='bfill')
df4
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192           The National Exemplar
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263        Downtown Raleigh Alliance
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# ...

# %%
# import library
import numpy as np
from scipy import stats

# %%
# to access the column labels
df2.columns
# Out:
# Index(['job_id', 'company_name', 'title', 'description', 'max_salary',
#        'pay_period', 'location', 'company_id', 'views', 'med_salary',
#        'min_salary', 'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'job_posting_url', 'application_url',
#        'application_type', 'expiry', 'closed_time',
#        'formatted_experience_level', 'skills_desc', 'listed_time',
#        'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type'],
#       dtype='object')

# %%
# permanently remove the column named 'formatted_experience_level' from the DataFrame df2
df2.drop(['formatted_experience_level'],axis=1,inplace=True)
df2.columns
# Out:
# Index(['job_id', 'company_name', 'title', 'description', 'max_salary',
#        'pay_period', 'location', 'company_id', 'views', 'med_salary',
#        'min_salary', 'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'job_posting_url', 'application_url',
#        'application_type', 'expiry', 'closed_time', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type'],
#       dtype='object')
